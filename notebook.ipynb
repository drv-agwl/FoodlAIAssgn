# %% [markdown]
# # **Foodl AI Task Phase**
#
# One of the critical tasks in FoodlAI is accessing various stages of cooking an ingredient. With the help of computer vision, we aim to solve this by creating robust models which can be generalized to any cuisine. As you will work closely with these models, we want you to be familiarized with our working environments. This task phase analyzes your critical thinking, problem-solving, programming, and time management.

# %% [markdown]
# ![Screenshot (2).png](data:image/png;base64,...)

# %% [markdown]
# ## Problem Statement
#
# The dataset consists of visual, thermal and gas sensor data of tomato being cooked. The aim is to create a model that uses all the three modalities and can predict various stages of tomato being cooked. There are several sub-tasks that will guide you through the task phase.
#
# PyTorch is recommended for this task phase. However, you can use any framework you like.
#
# Please make this notebook self-explanatory. Provide comments wherever necessary.
#
# **Dataset:**
#
# You can use any of the below dataset to build your model:
# [Dataset](https://drive.google.com/file/d/1odItt0IsgY5_mhg7OTXo2APvb14F4wfM/view?usp=sharing)
#
# **Notes:**
#
# 1. Please provide Training and Validation loss graphs for each task below. Comment on those graphs.
# 2. Compare the Training, Validation and Testing scores.
# 3. Provide reasoning behind dataset split.
# 4. Display the prediction results. Provide 5 cases where your model is failing.
# 5. Make a cell for single data point inference.
# 6. All the models should be trained in less than 100 epochs.
# 7. You may use a Weights and Biases report for logging various metrics.
#
# **Submission:**
# Please work on the copy version of this notebook. Once you have completed the task phase, you can send the link of the notebook.

# %% [markdown]
# ### Task 1 - Preprocessing:
#
# The various data from the modalities are not in sync as in the number of rgb & ir images are not the same. Similar trends can be observed for gas sensor data. So you need to apply proper data preprocessing techniques to improve the quality of individual modality as well the entire dataset. Do provide proper justification for the techniques that you're using.

# %% [markdown]
# ### Task 2 - A Classification Model
#
# Your model should be able to classify various stages of the tomato being cooked
#
# **Labeling strategy:** Because this is an open problem, you can label the images as your choice.
#
# **Architecture:** You are allowed to use any deep learning architechture.
#
# Please provide your Hyperparameter tuning strategy

# %%
"""
A Labeling Example: You can split the dataset into ten classes if there are 200 images in your dataset.
In that case, each class would contain 20 data points. And the number of labels should represent
the stages of tomato being cooked. Zero will indicate that cooking hasn't been started,
and nine will signal that cooking has been done. Concisely the labels should indicate the
percent of tomato cooking that has been done.

"""
# Out:
# "\nA Labeling Example: You can split the dataset into ten classes if there are 200 images in your dataset.\nIn that case, each class would contain 20 data points. And the number of labels should represent\nthe stages of tomato being cooked. Zero will indicate that cooking hasn't been started,\nand nine will signal that cooking has been done. Concisely the labels should indicate the\npercent of tomato cooking that has been done.\n\n"

# %% [markdown]
# ### Task 3 - A Regression Model
#
# Using a similar model, can you perform the same task as regression model.
#
# Please provide your Hyperparameter tuning strategy

# %%
"""
A Labeling Example: The timestamps of the video can be used as regression labels.
In the end, the labels should always indicate the percent of cooking done.

"""
# Out:
# '\nA Labeling Example: The timestamps of the video can be used as regression labels.\nIn the end, the labels should always indicate the percent of cooking done.\n\n'

# %% [markdown]
# ### Task 5 - Model Improvisation
# Can you improve some aspects of your model and show the performance against old ones?
#
# They can be adding or removing layers, addition of blocks. But, Hyperparameter Tuning is not considered a part of this task. Only architectural changes.

# %% [markdown]
# ### (Bonus)
# Can you deploy your model in as a interactive web application?

# %% [markdown]
# All the best for your task phase!
#
# *Foodl AI Team*
